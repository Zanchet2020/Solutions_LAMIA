# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9472 - loss: 0.0754
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9495 - loss: 0.0992
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9580 - loss: 0.0793
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9483 - loss: 0.0845
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9591 - loss: 0.0930
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9444 - loss: 0.1547
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9576 - loss: 0.1071
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9513 - loss: 0.1078
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9478 - loss: 0.1016
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9382 - loss: 0.1057
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9308 - loss: 0.1060
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9356 - loss: 0.1374
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9520 - loss: 0.1095

# %%
inverse_word_index = {v: k for k, v in tokenizer.word_index.items()}
seed_text = "I made a poetry machine"
next_words = 20
for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen = max_sequence_len-1, padding='pre')
    predicted = model.predict(token_list, verbose=0)
    print(np.argmax(predicted))
    output_word = inverse_word_index[np.argmax(predicted) + 1]
    seed_text += ' ' + output_word

print(seed_text)
# Out:
# 221
# 223
# 29
# 3
# 3
# 143
# 22
# 231
# 3
# 231
# 231
# 22
# 3
# 143
# 267
# 261
# 127
# 215
# 231
# 231
# I made a poetry machine drop much him in in old got saw in saw saw got in old end squeezed potatoes some saw saw

# %%
tokenizer.word_index
# Out:
# {'and': 1,
#  'the': 2,
#  'a': 3,
#  'in': 4,
#  'all': 5,
#  'i': 6,
#  'of': 7,
#  "lanigan's": 8,
#  'ball': 9,
#  'for': 10,
#  'to': 11,
#  'at': 12,
#  'were': 13,
#  'she': 14,
#  'stepped': 15,
#  'he': 16,
#  'his': 17,
#  'girls': 18,
#  'as': 19,
#  'they': 20,
#  "'til": 21,
#  'again': 22,
#  'got': 23,
#  'boys': 24,
#  "'round": 25,
#  'that': 26,
#  'her': 27,
#  'there': 28,
#  'out': 29,
#  'him': 30,
#  'six': 31,
#  'long': 32,
#  'months': 33,
#  'spent': 34,
#  'learning': 35,
#  'was': 36,
#  'away': 37,
#  'left': 38,
#  'friends': 39,
#  'relations': 40,
#  'when': 41,
#  'dublin': 42,
#  'doing': 43,
#  'myself': 44,
#  'nice': 45,
#  'just': 46,
#  'dancing': 47,
#  'merry': 48,
#  'tipped': 49,
#  'me': 50,
#  'soon': 51,
#  'time': 52,
#  'their': 53,
#  'them': 54,
#  'danced': 55,
#  'new': 56,
#  'steps': 57,
#  'an': 58,
#  'put': 59,
#  'leg': 60,
#  'miss': 61,
#  'fainted': 62,
#  'from': 63,
#  'up': 64,
#  'town': 65,
#  'athy': 66,
#  'one': 67,
#  'jeremy': 68,
#  'lanigan': 69,
#  'battered': 70,
#  "hadn't": 71,
#  'pound': 72,
#  'father': 73,
#  'died': 74,
#  'made': 75,
#  'man': 76,
#  'farm': 77,
#  'ten': 78,
#  'acres': 79,
#  'ground': 80,
#  'gave': 81,
#  'grand': 82,
#  'party': 83,
#  'who': 84,
#  "didn't": 85,
#  'forget': 86,
#  'it': 87,
#  'comes': 88,
#  'will': 89,
#  'if': 90,
#  "you'll": 91,
#  'but': 92,
#  'listen': 93,
#  "i'll": 94,
#  'make': 95,
#  'your': 96,
#  'eyes': 97,
#  'glisten': 98,
#  'rows': 99,
#  'ructions': 100,
#  'nothing': 101,
#  'dance': 102,
#  'be': 103,
#  'sure': 104,
#  'free': 105,
#  'invitation': 106,
#  'might': 107,
#  'ask': 108,
#  'minute': 109,
#  'both': 110,
#  'bees': 111,
#  'cask': 112,
#  'judy': 113,
#  "o'daly": 114,
#  'little': 115,
#  'milliner': 116,
#  'wink': 117,
#  'give': 118,
#  'call': 119,
#  'arrived': 120,
#  'with': 121,
#  'peggy': 122,
#  'mcgilligan': 123,
#  'lashings': 124,
#  'punch': 125,
#  'wine': 126,
#  'ladies': 127,
#  'potatoes': 128,
#  'cakes': 129,
#  'bacon': 130,
#  'tea': 131,
#  'nolans': 132,
#  'dolans': 133,
#  "o'gradys": 134,
#  'courting': 135,
#  'songs': 136,
#  'went': 137,
#  'plenty': 138,
#  'water': 139,
#  'harp': 140,
#  'once': 141,
#  'sounded': 142,
#  "tara's": 143,
#  'old': 144,
#  'hall': 145,
#  'sweet': 146,
#  'nelly': 147,
#  'gray': 148,
#  'rat': 149,
#  "catcher's": 150,
#  'daughter': 151,
#  'singing': 152,
#  'together': 153,
#  'kinds': 154,
#  'nonsensical': 155,
#  'polkas': 156,
#  'room': 157,
#  'whirligig': 158,
#  'julia': 159,
#  'we': 160,
#  'banished': 161,
#  'nonsense': 162,
#  'twist': 163,
#  'reel': 164,
#  'jig': 165,
#  "'och": 166,
#  'mavrone': 167,
#  'how': 168,
#  'mad': 169,
#  "you'd": 170,
#  'think': 171,
#  'ceiling': 172,
#  'would': 173,
#  'fall': 174,
#  'three': 175,
#  'weeks': 176,
#  "brooks'": 177,
#  'academy': 178,
#  'hearty': 179,
#  'around': 180,
#  'couples': 181,
#  'groups': 182,
#  'accident': 183,
#  'happened': 184,
#  'young': 185,
#  'terrance': 186,
#  'mccarthy': 187,
#  'right': 188,
#  'through': 189,
#  "finnerty's": 190,
#  'hoops': 191,
#  'poor': 192,
#  'creature': 193,
#  'cried': 194,
#  'meelia': 195,
#  'murther': 196,
#  "''": 197,
#  'called': 198,
#  'brothers': 199,
#  'gathered': 200,
#  'carmody': 201,
#  'swore': 202,
#  "he'd": 203,
#  'go': 204,
#  'no': 205,
#  'further': 206,
#  'had': 207,
#  'satisfaction': 208,
#  'midst': 209,
#  'row': 210,
#  'kerrigan': 211,
#  'cheeks': 212,
#  'same': 213,
#  'red': 214,
#  'rose': 215,
#  'some': 216,
#  'lads': 217,
#  'declared': 218,
#  'painted': 219,
#  'took': 220,
#  'small': 221,
#  'drop': 222,
#  'too': 223,
#  'much': 224,
#  'suppose': 225,
#  'sweetheart': 226,
#  'ned': 227,
#  'morgan': 228,
#  'so': 229,
#  'powerful': 230,
#  'able': 231,
#  'saw': 232,
#  'fair': 233,
#  'colleen': 234,
#  'stretched': 235,
#  'by': 236,
#  'wall': 237,
#  'tore': 238,
#  'under': 239,
#  'table': 240,
#  'smashed': 241,
#  'chaneys': 242,
#  'oh': 243,
#  "'twas": 244,
#  'then': 245,
#  'runctions': 246,
#  'lick': 247,
#  'big': 248,
#  'phelim': 249,
#  'mchugh': 250,
#  'replied': 251,
#  'introduction': 252,
#  'kicked': 253,
#  'terrible': 254,
#  'hullabaloo': 255,
#  'ould': 256,
#  'casey': 257,
#  'piper': 258,
#  'near': 259,
#  'being': 260,
#  'strangled': 261,
#  'squeezed': 262,
#  'pipes': 263,
#  'bellows': 264,
#  'chanters': 265,
#  'ribbons': 266,
#  'entangled': 267,
#  'end': 268}
