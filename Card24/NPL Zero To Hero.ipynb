# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
# Out:
# 2024-11-19 10:22:06.682712: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-19 10:22:06.692509: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-19 10:22:06.704413: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-19 10:22:06.707903: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-19 10:22:06.716333: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-19 10:22:07.356270: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
sentences = [
    "I love my dog",
    "I love my cat"
]

# %%
tokenizer = Tokenizer(num_words=100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'<OOV>': 1, 'i': 2, 'love': 3, 'my': 4, 'dog': 5, 'cat': 6}

# %%
sentences = [
    "I love my dog",
    "I love my cat",
    "You love my dog!"
]

# %%
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(sentences)

# %%
word_index
# Out:
# {'<OOV>': 1, 'love': 2, 'my': 3, 'i': 4, 'dog': 5, 'cat': 6, 'you': 7}

# %%
sequences
# Out:
# [[4, 2, 3, 5], [4, 2, 3, 6], [7, 2, 3, 5]]

# %%
sentences = [
    "I love my dog",
    "I love my cat",
    "You love my dog!",
    "Do you think my dog is amazing?"
]

# %%
sequences = tokenizer.texts_to_sequences(sentences)

# %%
sequences
# Out:
# [[4, 2, 3, 5], [4, 2, 3, 6], [7, 2, 3, 5], [1, 7, 1, 3, 5, 1, 1]]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padded = pad_sequences(sequences)

# %%
padded
# Out:
# array([[0, 0, 0, 4, 2, 3, 5],
#        [0, 0, 0, 4, 2, 3, 6],
#        [0, 0, 0, 7, 2, 3, 5],
#        [1, 7, 1, 3, 5, 1, 1]], dtype=int32)

# %%
text = []
with open("shrek.txt") as file:
    text.append(file.read())

# %%
tokenizer = Tokenizer(num_words=100000, oov_token="<OOV>")

# %%
tokenizer.fit_on_texts(text)

# %%
len(tokenizer.word_counts)
# Out:
# 1628

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('man', 21),
#              ('once', 3),
#              ('upon', 3),
#              ('a', 226),
#              ('time', 18),
#              ('there', 30),
#              ('was', 38),
#              ('lovely', 4),
#              ('princess', 51),
#              ('but', 64),
#              ('she', 17),
#              ('had', 9),
#              ('an', 24),
#              ('enchantment', 1),
#              ('her', 33),
#              ('of', 91),
#              ('fearful', 1),
#              ('sort', 1),
#              ('which', 4),
#              ('could', 9),
#              ('only', 15),
#              ('be', 43),
#              ('broken', 3),
#              ('by', 21),
#              ("love's", 10),
#              ('first', 13),
#              ('kiss', 11),
#              ('locked', 3),
#              ('away', 13),
#              ('in', 75),
#              ('castle', 3),
#              ('guarded', 2),
#              ('terrible', 1),
#              ('fire', 6),
#              ('breathing', 3),
#              ('dragon', 14),
#              ('many', 1),
#              ('brave', 4),
#              ('knigts', 1),
#              ('attempted', 1),
#              ('to', 170),
#              ('free', 3),
#              ('from', 22),
#              ('this', 83),
#              ('dreadful', 1),
#              ('prison', 1),
#              ('non', 1),
#              ('prevailed', 1),
#              ('waited', 1),
#              ('the', 242),
#              ("dragon's", 1),
#              ('keep', 14),
#              ('highest', 2),
#              ('room', 3),
#              ('tallest', 2),
#              ('tower', 5),
#              ('for', 57),
#              ('true', 22),
#              ('love', 35),
#              ('and', 129),
#              ('laughing', 8),
#              ('like', 59),
#              ("that's", 46),
#              ('ever', 10),
#              ('gonna', 24),
#              ('happen', 2),
#              ('paper', 1),
#              ('rusting', 1),
#              ('toilet', 1),
#              ('flushes', 1),
#              ('what', 98),
#              ('load', 1),
#              ('somebody', 6),
#              ('told', 5),
#              ('me', 137),
#              ('world', 5),
#              ('is', 89),
#              ('roll', 1),
#              ('i', 324),
#              ("ain't", 8),
#              ('sharpest', 1),
#              ('tool', 1),
#              ('shed', 1),
#              ("lookin'", 3),
#              ('kind', 8),
#              ('dumb', 2),
#              ('with', 32),
#              ('finger', 1),
#              ('thumb', 1),
#              ('shape', 1),
#              ('l', 1),
#              ('on', 76),
#              ('forehead', 1),
#              ('years', 5),
#              ('start', 6),
#              ("comin'", 5),
#              ('they', 22),
#              ("don't", 86),
#              ('stop', 6),
#              ('fed', 1),
#              ('rules', 2),
#              ('hit', 1),
#              ('ground', 1),
#              ("runnin'", 1),
#              ("didn't", 9),
#              ('make', 18),
#              ('sense', 1),
#              ('not', 62),
#              ('live', 7),
#              ('fun', 4),
#              ('your', 62),
#              ('brain', 1),
#              ('gets', 4),
#              ('smart', 1),
#              ('head', 6),
#              ('so', 40),
#              ('much', 9),
#              ('do', 64),
#              ('see', 23),
#              ("what's", 13),
#              ('wrong', 5),
#              ("takin'", 1),
#              ('backstreets', 1),
#              ("you'll", 4),
#              ('never', 14),
#              ('know', 70),
#              ('if', 31),
#              ('you', 375),
#              ('go', 43),
#              ('shine', 3),
#              ('glow', 1),
#              ('hey', 44),
#              ('now', 50),
#              ("you're", 59),
#              ('all', 72),
#              ('star', 6),
#              ('get', 56),
#              ('game', 3),
#              ('play', 5),
#              ('rock', 4),
#              ('show', 7),
#              ('paid', 4),
#              ('that', 99),
#              ('glitters', 3),
#              ('gold', 3),
#              ("shootin'", 3),
#              ('stars', 5),
#              ('break', 7),
#              ('mold', 3),
#              ("it's", 70),
#              ('cool', 5),
#              ('place', 8),
#              ('say', 15),
#              ('it', 100),
#              ('colder', 1),
#              ('bundled', 1),
#              ('up', 28),
#              ('wait', 21),
#              ('till', 2),
#              ('older', 1),
#              ('meteor', 1),
#              ('men', 6),
#              ('beg', 2),
#              ('differ', 1),
#              ('judging', 1),
#              ('hole', 1),
#              ('satellite', 1),
#              ('picture', 1),
#              ('ice', 1),
#              ('we', 43),
#              ('skate', 1),
#              ("gettin'", 2),
#              ('pretty', 4),
#              ('thin', 1),
#              ("water's", 1),
#              ('getting', 7),
#              ('warm', 1),
#              ('might', 5),
#              ('as', 19),
#              ('well', 41),
#              ('swim', 1),
#              ('my', 88),
#              ("world's", 1),
#              ('how', 14),
#              ("'bout", 2),
#              ('yours', 2),
#              ('way', 29),
#              ("i'll", 30),
#              ('bored', 1),
#              ('shouting', 3),
#              ('belches', 4),
#              ('record', 1),
#              ('scratching', 1),
#              ('think', 21),
#              ('right', 62),
#              ("let's", 11),
#              ('whoa', 11),
#              ('hold', 9),
#              ('thing', 13),
#              ('can', 37),
#              ('yeah', 36),
#              ("it'll", 3),
#              ('grind', 1),
#              ('bones', 3),
#              ('bread', 2),
#              ('laughs', 14),
#              ('yes', 20),
#              ('actually', 3),
#              ('would', 13),
#              ('gaint', 1),
#              ('ogres', 1),
#              ("they're", 4),
#              ('worse', 1),
#              ("they'll", 2),
#              ('suit', 1),
#              ('freshly', 1),
#              ('peeled', 1),
#              ('skin', 1),
#              ('no', 133),
#              ('shave', 1),
#              ('liver', 1),
#              ('squeeze', 1),
#              ('jelly', 1),
#              ('eyes', 7),
#              ('quite', 3),
#              ('good', 32),
#              ('toast', 1),
#              ('back', 26),
#              ('beast', 8),
#              ('warn', 2),
#              ('ya', 12),
#              ('gasping', 11),
#              ('roaring', 7),
#              ('whispers', 2),
#              ('part', 1),
#              ('where', 21),
#              ('run', 7),
#              ('stay', 18),
#              ('out', 31),
#              ('wanted', 6),
#              ('fairy', 4),
#              ('tale', 4),
#              ('creatures', 3),
#              ('sighs', 24),
#              ("man's", 1),
#              ('voice', 2),
#              ("one's", 2),
#              ('full', 2),
#              ('take', 20),
#              ('gasps', 18),
#              ('move', 6),
#              ('along', 3),
#              ('come', 26),
#              ('next', 6),
#              ('give', 17),
#              ('fiying', 1),
#              ('days', 2),
#              ('are', 62),
#              ('over', 14),
#              ('20', 1),
#              ('pieces', 2),
#              ('silver', 1),
#              ('witch', 2),
#              ('twenty', 1),
#              ('thudding', 1),
#              ('sit', 3),
#              ('down', 22),
#              ('quiet', 3),
#              ('crying', 1),
#              ('cage', 1),
#              ('too', 9),
#              ('small', 2),
#              ('please', 17),
#              ('turn', 7),
#              ('stubborn', 2),
#              ('again', 8),
#              ('change', 2),
#              ('another', 6),
#              ('chance', 3),
#              ('oh', 126),
#              ('shut', 5),
#              ('have', 57),
#              ('got', 21),
#              ('little', 23),
#              ('wooden', 1),
#              ('puppet', 2),
#              ("i'm", 105),
#              ('real', 3),
#              ('boy', 4),
#              ('five', 1),
#              ('shillings', 2),
#              ('possessed', 1),
#              ('toy', 1),
#              ('father', 1),
#              ('let', 14),
#              ('them', 10),
#              ('help', 6),
#              ("i've", 11),
#              ('talking', 9),
#              ('donkey', 37),
#              ('grunts', 15),
#              ('ten', 2),
#              ('prove', 2),
#              ('ahead', 6),
#              ('fella', 1),
#              ("he's", 12),
#              ('just', 59),
#              ('nervous', 2),
#              ('really', 35),
#              ('chatterbox', 1),
#              ('talk', 12),
#              ('boneheaded', 1),
#              ('dolt', 1),
#              ('heard', 7),
#              ('enough', 7),
#              ('guards', 4),
#              ('he', 24),
#              ('talks', 2),
#              ('does', 7),
#              ('talkingest', 1),
#              ('damn', 8),
#              ('saw', 5),
#              ('sight', 3),
#              ('swear', 1),
#              ('fly', 4),
#              ('ha', 11),
#              ('fool', 1),
#              ('flying', 2),
#              ('seen', 6),
#              ('housefly', 1),
#              ('maybe', 10),
#              ('even', 5),
#              ('superfly', 1),
#              ('bet', 1),
#              ('seize', 1),
#              ('him', 25),
#              ('after', 5),
#              ('orge', 24),
#              ('aye', 2),
#              ('order', 4),
#              ('lord', 19),
#              ('farquaad', 16),
#              ('am', 8),
#              ('authorized', 1),
#              ('both', 7),
#              ('under', 1),
#              ('arrest', 1),
#              ('transport', 1),
#              ('designated', 1),
#              ('resettlement', 1),
#              ('facility', 1),
#              ('army', 1),
#              ('whimpering', 6),
#              ('chuckles', 9),
#              ('something', 15),
#              ('listen', 7),
#              ("somethin'", 1),
#              ('here', 28),
#              ('incredible', 1),
#              ("talkin'", 6),
#              ('tell', 26),
#              ('great', 8),
#              ('those', 8),
#              ('thought', 9),
#              ('then', 16),
#              ('showed', 1),
#              ('bam', 1),
#              ("trippin'", 1),
#              ('themselves', 1),
#              ('babes', 1),
#              ('woods', 3),
#              ('made', 2),
#              ('feel', 7),
#              ('why', 19),
#              ('celebrate', 1),
#              ('freedom', 1),
#              ('own', 4),
#              ('friends', 11),
#              ('hmm', 5),
#              ('uh', 47),
#              ('any', 7),
#              ("goin'", 6),
#              ('myself', 4),
#              ('minute', 3),
#              ('idea', 4),
#              ('stick', 2),
#              ('mean', 19),
#              ('green', 2),
#              ("fightin'", 1),
#              ('machine', 1),
#              ('together', 6),
#              ("we'll", 4),
#              ('scare', 1),
#              ('spit', 2),
#              ('anybody', 1),
#              ('crosses', 1),
#              ('us', 8),
#              ('wow', 14),
#              ('scary', 1),
#              ('mind', 10),
#              ("sayin'", 2),
#              ('work', 3),
#              ('breath', 2),
#              ('certainly', 2),
#              ('will', 17),
#              ('job', 4),
#              ('done', 2),
#              ("'cause", 13),
#              ('definitely', 1),
#              ('need', 6),
#              ('some', 12),
#              ('tic', 1),
#              ('tacs', 1),
#              ('or', 10),
#              ('stinks', 1),
#              ('almost', 1),
#              ('burned', 2),
#              ('hair', 2),
#              ('outta', 1),
#              ('nose', 1),
#              ('mumbling', 2),
#              ('than', 6),
#              ('ate', 3),
#              ('rotten', 1),
#              ('berries', 1),
#              ('strong', 1),
#              ('gases', 1),
#              ('eking', 1),
#              ('butt', 3),
#              ('day', 9),
#              ('following', 1),
#              ('alone', 8),
#              ("there's", 29),
#              ('one', 36),
#              ('beside', 3),
#              ('promlems', 1),
#              ('gone', 3),
#              ('deride', 1),
#              ('gotta', 8),
#              ('heve', 1),
#              ('singing', 2),
#              ('wonder', 1),
#              ('friend', 1),
#              ('cruelly', 1),
#              ('honest', 2),
#              ('look', 43),
#              ('at', 24),
#              ('tall', 1),
#              ('grab', 1),
#              ('torch', 1),
#              ('pitchforks', 1),
#              ("doesn't", 4),
#              ('bother', 1),
#              ('nope', 1),
#              ('name', 3),
#              ('shrek', 67),
#              ('about', 28),
#              ('care', 4),
#              ('nobody', 4),
#              ('thinks', 2),
#              ('respect', 1),
#              ('whoo', 3),
#              ("who'd", 1),
#              ('want', 15),
#              ('home', 12),
#              ('beautiful', 6),
#              ('decorator', 1),
#              ('amazing', 3),
#              ("you've", 4),
#              ('such', 6),
#              ('modest', 1),
#              ('budget', 1),
#              ('boulder', 2),
#              ('nice', 3),
#              ('guess', 10),
#              ('entertain', 1),
#              ('privacy', 2),
#              ('common', 2),
#              ('hate', 1),
#              ('when', 23),
#              ('face', 7),
#              ('trying', 2),
#              ('hint', 2),
#              ("won't", 4),
#              ('leave', 5),
#              ('awkward', 1),
#              ('silence', 2),
#              ('course', 3),
#              ('wanna', 18),
#              ('considered', 1),
#              ('freak', 2),
#              ('okay', 37),
#              ('night', 17),
#              ('ah', 9),
#              ('thank', 3),
#              ('late', 6),
#              ("swappin'", 1),
#              ('manly', 1),
#              ('stories', 2),
#              ("mornin'", 1),
#              ("makin'", 1),
#              ('waffles', 1),
#              ('sleep', 1),
#              ('outside', 7),
#              ('best', 5),
#              ('sniffles', 1),
#              ('outdoors', 1),
#              ('born', 1),
#              ('sitting', 1),
#              ('bubbling', 1),
#              ('creaking', 3),
#              ('clattering', 2),
#              ('gents', 1),
#              ('far', 3),
#              ('cry', 3),
#              ('farm', 1),
#              ('choice', 1),
#              ('fune', 1),
#              ('bed', 1),
#              ('sniffs', 6),
#              ('found', 2),
#              ('cheese', 1),
#              ('ow', 8),
#              ('blah', 1),
#              ('awful', 3),
#              ('stuff', 3),
#              ('gorder', 1),
#              ('did', 13),
#              ('doing', 12),
#              ('house', 1),
#              ('snickers', 1),
#              ('dead', 4),
#              ('broad', 1),
#              ('off', 17),
#              ('table', 1),
#              ('supposed', 4),
#              ('put', 7),
#              ("bed's", 1),
#              ('taken', 1),
#              ('huh', 11),
#              ('gusps', 1),
#              ('male', 1),
#              ('swamp', 20),
#              ('signs', 1),
#              ('terrifying', 1),
#              ('aah', 10),
#              ('cackling', 1),
#              ('quit', 1),
#              ('push', 1),
#              ('squeaking', 1),
#              ('lows', 1),
#              ('echoing', 1),
#              ('dear', 1),
#              ('hapaya', 2),
#              ('quickly', 1),
#              ('invite', 1),
#              ('gosh', 1),
#              ('invited', 1),
#              ('were', 6),
#              ('forced', 1),
#              ('who', 16),
#              ('huffed', 1),
#              ('und', 2),
#              ('puffed', 1),
#              ('signed', 1),
#              ('eviction', 1),
#              ('notice', 1),
#              ('knows', 1),
#              ('guy', 4),
#              ('murmuring', 3),
#              ('anyone', 6),
#              ('else', 6),
#              ('find', 13),
#              ('pick', 2),
#              ('fine', 5),
#              ('attention', 2),
#              ('things', 7),
#              ('comfortable', 1),
#              ('welcome', 3),
#              ('officially', 1),
#              ('worn', 1),
#              ('fact', 1),
#              ('land', 4),
#              ('came', 2),
#              ('cheering', 6),
#              ('twittering', 1),
#              ('hear', 5),
#              ('two', 13),
#              ('stalwart', 1),
#              ('whirlwind', 1),
#              ('big', 8),
#              ('city', 1),
#              ('adventure', 1),
#              ('road', 3),
#              ('sing', 2),
#              ("can't", 15),
#              ('whistle', 2),
#              ('hum', 2),
#              ('humming', 2),
#              ('ready', 2),
#              ('coughing', 1),
#              ('clears', 2),
#              ('throat', 3),
#              ('fust', 1),
#              ('catch', 1),
#              ('gingerbread', 1),
#              ('monster', 4),
#              ('rest', 3),
#              ('trash', 1),
#              ('poisoning', 1),
#              ('perfect', 13),
#              ('others', 1),
#              ('eat', 5),
#              ('tried', 3),
#              ('fair', 2),
#              ('patience', 1),
#              ('has', 8),
#              ('reached', 1),
#              ('its', 1),
#              ('end', 1),
#              ('buttons', 2),
#              ('gumdrop', 1),
#              ("who's", 3),
#              ('hiding', 1),
#              ('muffin', 8),
#              ('lives', 5),
#              ('drury', 1),
#              ('lane', 1),
#              ("she's", 10),
#              ('married', 3),
#              ('door', 4),
#              ('opens', 2),
#              ('waiting', 3),
#              ('bring', 1),
#              ('grunting', 2),
#              ('magic', 1),
#              ('mirror', 5),
#              ('anything', 5),
#              ('ginerbread', 1),
#              ('evening', 1),
#              ('wall', 4),
#              ('most', 2),
#              ('kingdom', 2),
#              ('technically', 1),
#              ('king', 9),
#              ('thelonius', 1),
#              ('saying', 4),
#              ('yet', 3),
#              ('become', 2),
#              ('marry', 7),
#              ('relax', 1),
#              ('because', 6),
#              ('meet', 1),
#              ("today's", 1),
#              ('eligible', 1),
#              ('bachelorettes', 1),
#              ('bachelorette', 6),
#              ('number', 8),
#              ('mentally', 1),
#              ('abused', 1),
#              ('likes', 7),
#              ('sushi', 1),
#              ('hot', 2),
#              ('tubbing', 1),
#              ('anytime', 1),
#              ('hobbies', 1),
#              ('include', 1),
#              ('cooking', 1),
#              ('cleaning', 1),
#              ('evil', 1),
#              ('sisters', 1),
#              ('cinderella', 1),
#              ('cape', 1),
#              ('wearing', 1),
#              ('girl', 8),
#              ('fancy', 1),
#              ('although', 1),
#              ('seven', 1),
#              ('other', 5),
#              ('easy', 4),
#              ('frozen', 1),
#              ('lips', 1),
#              ('wire', 1),
#              ('snow', 1),
#              ('white', 3),
#              ('last', 8),
#              ('three', 11),
#              ('fiery', 2),
#              ('redhead', 1),
#              ('surrounded', 1),
#              ('boiling', 2),
#              ('lava', 2),
#              ('loaded', 1),
#              ('pistol', 1),
#              ('pina', 2),
#              ('colads', 1),
#              ('caught', 2),
#              ('rain', 2),
#              ('rescuing', 3),
#              ('fiona', 20),
#              ('shudders', 1),
#              ('chosen', 1),
#              ('coladas', 1),
#              ('into', 8),
#              ('yoga', 1),
#              ('someone', 4),
#              ('probably', 2),
#              ('should', 6),
#              ('mention', 1),
#              ('happens', 3),
#              ('sunset', 3),
#              ('queen', 2),
#              ('duloc', 12),
#              ('finally', 2),
#              ('captain', 2),
#              ('assemble', 1),
#              ('finest', 1),
#              ("we're", 6),
#              ('going', 7),
#              ('tournament', 2),
#              ("i'd", 7),
#              ('must', 5),
#              ("farquaad's", 3),
#              ('compensating', 2),
#              ('groans', 5),
#              ('hurry', 2),
#              ('darling', 2),
#              ('screams', 10),
#              ('second', 2),
#              ('turnstile', 1),
#              ('clatters', 1),
#              ('everybody', 4),
#              ('whirring', 2),
#              ('clicking', 1),
#              ('town', 1),
#              ('lay', 2),
#              ('waves', 1),
#              ('line', 3),
#              ('grass', 1),
#              ('shoes', 1),
#              ('wipe', 1),
#              ('camera', 1),
#              ('shutter', 1),
#              ('clicks', 1),
#              ('trumpet', 1),
#              ('fanfare', 2),
#              ('crowd', 4),
#              ('knights', 4),
#              ('brightest', 1),
#              ('today', 9),
#              ('shall', 6),
#              ('himself', 1),
#              ('smacked', 1),
#              ('bottom', 1),
#              ('sorry', 8),
#              ('champion', 4),
#              ('honor', 2),
#              ('privilege', 1),
#              ('forth', 2),
#              ('rescue', 11),
#              ('reason', 2),
#              ('winner', 1),
#              ('unsuccessful', 1),
#              ('runner', 1),
#              ('his', 7),
#              ('mae', 1),
#              ('die', 7),
#              ('sacrifice', 1),
#              ('willing', 1),
#              ('begin', 1),
#              ('hideous', 4),
#              ('very', 6),
#              ('indeed', 2),
#              ('new', 6),
#              ('plan', 2),
#              ('kills', 1),
#              ('named', 1),
#              ('hang', 1),
#              ('settle', 1),
#              ('pint', 1),
#              ('kill', 1),
#              ('reputation', 4),
#              ('living', 2),
#              ('past', 1),
#              ('generation', 1),
#              ('whinnying', 1),
#              ('wants', 4),
#              ('bad', 10),
#              ('tag', 2),
#              ('said', 11),
#              ('improve', 1),
#              ('station', 1),
#              ('always', 7),
#              ("feelin'", 1),
#              ('having', 1),
#              ('chair', 2),
#              ('bell', 1),
#              ('dings', 1),
#              ('thursday', 1),
#              ('try', 3),
#              ('veal', 1),
#              ('sir', 4),
#              ('better', 10),
#              ('people', 7),
#              ('our', 13),
#              ('congratulations', 1),
#              ('won', 2),
#              ('embarking', 1),
#              ('noble', 4),
#              ('quest', 6),
#              ('already', 3),
#              ('dumped', 1),
#              ('deal', 1),
#              ('exactly', 2),
#              ('slime', 1),
#              ('covered', 1),
#              ('toadstool', 1),
#              ('squatters', 1),
#              ('straight', 2),
#              ('fight', 2),
#              ('filled', 2),
#              ('freaks', 1),
#              ('donkeys', 5),
#              ("shouldn't", 3),
#              ('pull', 1),
#              ('throttle', 1),
#              ('siege', 1),
#              ('fortress', 1),
#              ('grinds', 1),
#              ('whole', 6),
#              ('trip', 1),
#              ('decapitated', 1),
#              ('entire', 1),
#              ('village', 1),
#              ('their', 4),
#              ('heads', 1),
#              ('pike', 1),
#              ('gotten', 1),
#              ('knife', 1),
#              ('cut', 4),
#              ('open', 2),
#              ('spleen', 1),
#              ('drink', 1),
#              ('fluids', 1),
#              ('sound', 3),
#              ('information', 1),
#              ('lot', 6),
#              ('more', 4),
#              ('orges', 6),
#              ('example', 2),
#              ('um', 10),
#              ('onions', 5),
#              ('stink', 1),
#              ('sun', 4),
#              ('brown', 1),
#              ("sproutin'", 1),
#              ('hairs', 1),
#              ('layers', 10),
#              ('cake', 2),
#              ('loves', 1),
#              ('cakes', 3),
#              ('everyone', 4),
#              ('parfaits', 3),
#              ('met', 4),
#              ('person', 1),
#              ('parfait', 3),
#              ('delicious', 3),
#              ('dense', 1),
#              ('irritating', 1),
#              ('miniature', 1),
#              ('burden', 1),
#              ('story', 2),
#              ('bye', 2),
#              ('later', 1),
#              ('may', 2),
#              ('planet', 1),
#              ('preferred', 1),
#              ('tissure', 1),
#              ('making', 3),
#              ('mess', 2),
#              ('word', 4),
#              ('slobbering', 1),
#              ('misery', 2),
#              ('happiness', 3),
#              ('everything', 8),
#              ('receive', 1),
#              ('yonder', 2),
#              ('wander', 1),
#              ('ohh', 5),
#              ('before', 13),
#              ('crack', 1),
#              ('mouth', 1),
#              ('believe', 20),
#              ("you'd", 2),
#              ('brimstone', 4),
#              ('close', 1),
#              ('smell', 2),
#              ("wasn't", 5),
#              ('stone', 1),
#              ('neither', 2),
#              ('rumbling', 1),
#              ('sure', 5),
#              ('location', 1),
#              ('remember', 3),
#              ('bit', 1),
#              ('confession', 1),
#              ('wear', 1),
#              ('fear', 2),
#              ('sleeves', 3),
#              ('afraid', 8),
#              ('heights', 1),
#              ('uncomfortable', 1),
#              ('being', 3),
#              ('rickety', 1),
#              ('bridge', 1),
#              ('emotional', 1),
#              ('support', 1),
#              ('tackle', 1),
#              ('baby', 9),
#              ('step', 4),
#              ('makes', 7),
#              ('moving', 2),
#              ('god', 3),
#              ('halfway', 1),
#              ('half', 8),
#              ('safe', 1),
#              ('dance', 4),
#              ("doin'", 1),
#              ("that'll", 3),
#              ('pain', 1),
#              ('neck', 2),
#              ('anyway', 4),
#              ('inside', 3),
#              ('water', 1),
#              ('dripping', 1),
#              ('wind', 1),
#              ('howling', 1),
#              ('shh', 3),
#              ("nothin'", 3),
#              ("bein'", 1),
#              ("fear's", 1),
#              ('sensible', 1),
#              ('response', 1),
#              ('unfamiliar', 2),
#              ('situation', 3),
#              ('dangerous', 1),
#              ('add', 1),
#              ('breathes', 2),
#              ('eats', 1),
#              ('coward', 2),
#              ('scared', 1),
#              ('heck', 1),
#              ('stairs', 7),
#              ("she'll", 1),
#              ('read', 2),
#              ('book', 1),
#              ('handle', 2),
#              ('whip', 1),
#              ('creacing', 1),
#              ('drastic', 1),
#              ('steps', 1),
#              ('kick', 1),
#              ('curb', 1),
#              ('stair', 1),
#              ('master', 1),
#              ('mastered', 1),
#              ('wish', 1),
#              ('least', 3),
#              ("where's", 1),
#              ('roars', 6),
#              ('shouts', 1),
#              ('screaming', 3),
#              ('crowls', 2),
#              ('large', 1),
#              ('teeth', 2),
#              ('sparkling', 1),
#              ('food', 1),
#              ('bleach', 1),
#              ('dazzling', 1),
#              ('smile', 2),
#              ('detect', 1),
#              ('minty', 1),
#              ('freshness', 1),
#              ('reeking', 1),
#              ('feminine', 1),
#              ('beauty', 2),
#              ('matter', 2),
#              ('eye', 3),
#              ('coughs', 1),
#              ('asthmatic', 1),
#              ("it'd", 1),
#              ('blow', 1),
#              ('smoke', 1),
#              ('rings', 1),
#              ('vocalizing', 3),
#              ('wake', 4),
#              ('awaiting', 1),
#              ('knight', 6),
#              ('bold', 1),
#              ('ith', 1),
#              ...])
