# %%
import pandas as pd
import numpy as np
import torch
import cv2
import math
import os
import matplotlib.pyplot as plt
import zipfile

# %%
import tensorflow
from tensorflow.keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Input, Concatenate
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.models import model_from_json
from tensorflow.keras.preprocessing.image import ImageDataGenerator

tensorflow.__version__
# Out:
# 2024-10-29 11:24:39.443326: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-29 11:24:39.452817: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-29 11:24:39.464469: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-29 11:24:39.467701: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-29 11:24:39.476282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-29 11:24:40.130108: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# '2.17.0'

# %% [markdown]
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())
#
# gpus = tensorflow.config.list_physical_devices('GPU')
# if gpus:
#     try:
#         tensorflow.config.set_logical_device_configuration(gpus[0], [tensorflow.config.LogicalDeviceConfiguration(memory_limit=3900)])
#         logical_gpus = tensorflow.config.list_logical_devices('GPU')
#         print(len(gpus), "Phyisical GPUs, ", len(logical_gpus), "Logical GPUs")
#     except RuntimeError as e:
#         print(e)
#
#
# '''
# gpus = tensorflow.config.experimental.list_physical_devices('GPU')
# for gpu in gpus:
#   tensorflow.config.experimental.set_memory_growth(gpu, True)'''

# %%
df = pd.read_csv('./fer2013/fer2013.csv')
pixels = df['pixels'].to_list()

# %%
image_size = 48

# %%
faces = []
for image in pixels:
    face = [int(pixel) for pixel in image.split(' ')]
    face = np.asarray(face).reshape(image_size, image_size)
    faces.append(face)

# %%
faces = np.asarray(faces)

# %%
faces.shape
# Out:
# (35887, 48, 48)

# %%
faces = np.expand_dims(faces, -1)

# %%
faces.shape
# Out:
# (35887, 48, 48, 1)

# %%
def normalize(x):
    x = x.astype('float32')
    return x/255

faces = normalize(faces)

# %%
emocoes = pd.get_dummies(df['emotion']).values

# %%
emotions = ["Angry", "Disgusted", "Afraid", "Happy", "Neutral", "Sad", "Surprised"]

# %%
num_features = 64
num_labels = 7
batch_size = 64
epochs = 100
width, height = 48, 48
model = Sequential()
model.add(Conv2D(num_features, kernel_size=(3,3), activation='relu',
input_shape=(width, height, 1), data_format = 'channels_last',
kernel_regularizer = l2(0.01)))
model.add(Conv2D(num_features, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.5))
model.add(Conv2D(2*2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(2*2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*num_features, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_labels, activation = 'softmax'))
model.summary()
# Out:
# /home/zanchet/dev/LAMIA/LAMIA_venv/lib64/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730211905.855957   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.858167   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.859243   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.861244   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.862367   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.863374   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.953500   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.954676   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730211905.955725   11919 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-29 11:25:05.956770: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2172 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 46, 46, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 46, 46, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 23, 23, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 23, 23, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 23, 23, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 23, 23, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 11, 11, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 11, 11, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 11, 11, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 11, 11, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 11, 11, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 11, 11, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 5, 5, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 5, 5, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 5, 5, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 5, 5, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,905,863 (22.53 MB)
#  Trainable params: 5,902,151 (22.51 MB)
#  Non-trainable params: 3,712 (14.50 KB)

# %% [markdown]
# num_features = 64
# num_labels = 7 #len(emotions)
# epochs = 100
# batch_size = 8
# width, height = image_size, image_size
#
# i = Input(shape=(width, height, 1))
# x = Conv2D(num_features, kernel_size = (3,3), activation="relu", padding = 'same', kernel_regularizer = l2(0.01))(i)
# x = Conv2D(num_features, kernel_size = (3,3), activation="relu", padding="same")(x)
# x = BatchNormalization()(x)
# x = MaxPooling2D(pool_size=(2,2), strides=(2,2))(x)
# x = Dropout(0.3)(x)
#
# x = Conv2D(2*num_features, kernel_size = (3,3), activation="relu", padding="same")(x)
# x = BatchNormalization()(x)
# x = Conv2D(2*num_features, kernel_size = (3,3), activation="relu", padding="same")(x)
# x = BatchNormalization()(x)
# x = MaxPooling2D(pool_size=(2,2), strides=(2,2))(x)
# x = Dropout(0.3)(x)
#
# x = Conv2D(2*2*num_features, kernel_size = (3,3), activation="relu", padding="same")(x)
# x = BatchNormalization()(x)
# x = Conv2D(2*2*num_features, kernel_size = (3,3), activation="relu", padding="same")(x)
# x = BatchNormalization()(x)
# x = MaxPooling2D(pool_size=(2,2), strides=(2,2))(x)
# x = Dropout(0.3)(x)
#
# x = Conv2D(2*2*2*num_features, kernel_size = (3,3), activation="relu", padding="same")(x)
# x = BatchNormalization()(x)
# x = Conv2D(2*2*2*num_features, kernel_size = (3,3), activation="relu", padding="same")(x)
# x = BatchNormalization()(x)
# x = MaxPooling2D(pool_size=(2,2), strides=(2,2))(x)
# x = Dropout(0.3)(x)
#
# x = Flatten()(x)
#
# x = Dense(2*2*2*num_features, activation='relu')(x)
# x = Dropout(0.4)(x)
# x = Dense(2*2*num_features, activation='relu')(x)
# x = Dropout(0.4)(x)
# x = Dense(2*num_features, activation='relu')(x)
# x = Dropout(0.5)(x)
#
# o = Dense(num_labels, activation='softmax')(x)
#
# model = Model(inputs = i, outputs = o, name='Emotion_recon_3000')
#
# model.summary()
#
# #model.compile(optimizer = Adam(weight_decay=None, learning_rate=0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# num_features = 64
# num_labels = 7
# epochs = 100
# width, height = image_size, image_size
#
# model = Sequential()
#
# model.add(Conv2D(num_features, kernel_size=(3,3), activation='relu',
#                  input_shape=(width, height, 1), data_format = 'channels_last',
#                  kernel_regularizer = l2(0.01)))
# model.add(Conv2D(num_features, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# model.add(Dropout(0.5))
#
# model.add(Conv2D(2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(Conv2D(2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# model.add(Dropout(0.5))
#
# model.add(Conv2D(2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(Conv2D(2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# model.add(Dropout(0.5))
#
# model.add(Conv2D(2*2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(Conv2D(2*2*2*num_features, kernel_size=(3,3), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
# model.add(Dropout(0.5))
#
# model.add(Flatten())
#
# model.add(Dense(2*2*2*num_features, activation='relu'))
# model.add(Dropout(0.4))
# model.add(Dense(2*2*num_features, activation='relu'))
# model.add(Dropout(0.4))
# model.add(Dense(2*num_features, activation='relu'))
# model.add(Dropout(0.5))
#
# model.add(Dense(num_labels, activation = 'softmax'))
#
# model.summary()

# %%
model_file = 'expression_recognition_01.keras'

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = Adam(learning_rate = 0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics = ['accuracy'])

arquivo_modelo = 'modelo_01_expressoes.keras'

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor = 0.8, patience=3, verbose = 1)
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience = 8, verbose = 1, mode = 'auto')
checkpointer = ModelCheckpoint(arquivo_modelo, monitor='val_accuracy', verbose = 1, save_best_only=True)

# %% [markdown]
# history = model.fit(training_data_normalized,
#                     epochs = epochs,
#                     steps_per_epoch = 10,
#                     validation_data = validation_data_normalized,
#                     callbacks = [lr_reducer, checkpointer],
#                     validation_steps = 10)

# %%
X_train, X_val, y_train, y_val = train_test_split(faces, emocoes, test_size=0.15, random_state=42)

# %%
history = model.fit(np.array(X_train), np.array(y_train),
batch_size = batch_size,
epochs = epochs,
verbose = 1,
validation_data = (np.array(X_val), np.array(y_val)),
shuffle=True,
callbacks=[lr_reducer, checkpointer])
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730211942.135770   11990 service.cc:146] XLA service 0x7f3b5c013d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730211942.135793   11990 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-10-29 11:25:42.215905: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-29 11:25:42.619500: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#   3/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.1458 - loss: 5.8566
# I0000 00:00:1730211951.636147   11990 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2000 - loss: 2.3031
# 2024-10-29 11:26:26.817515: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_274', 8 bytes spill stores, 8 bytes spill loads
# Epoch 1: val_accuracy improved from -inf to 0.24276, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 49s 77ms/step - accuracy: 0.2000 - loss: 2.3025 - val_accuracy: 0.2428 - val_loss: 1.8187 - learning_rate: 0.0010
# Epoch 2/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2473 - loss: 1.8414
# Epoch 2: val_accuracy improved from 0.24276 to 0.24350, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 0.2473 - loss: 1.8414 - val_accuracy: 0.2435 - val_loss: 1.8181 - learning_rate: 0.0010
# Epoch 3/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2563 - loss: 1.8070
# Epoch 3: val_accuracy did not improve from 0.24350
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 0.2563 - loss: 1.8070 - val_accuracy: 0.1543 - val_loss: 2.0068 - learning_rate: 0.0010
# Epoch 4/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3084 - loss: 1.7166
# Epoch 4: val_accuracy did not improve from 0.24350
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.3084 - loss: 1.7165 - val_accuracy: 0.2403 - val_loss: 1.7515 - learning_rate: 0.0010
# Epoch 5/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3663 - loss: 1.6088
# Epoch 5: val_accuracy improved from 0.24350 to 0.39952, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.3663 - loss: 1.6087 - val_accuracy: 0.3995 - val_loss: 1.5222 - learning_rate: 0.0010
# Epoch 6/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4072 - loss: 1.5178
# Epoch 6: val_accuracy improved from 0.39952 to 0.40565, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.4072 - loss: 1.5178 - val_accuracy: 0.4056 - val_loss: 1.5084 - learning_rate: 0.0010
# Epoch 7/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4310 - loss: 1.4549
# Epoch 7: val_accuracy improved from 0.40565 to 0.43982, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.4310 - loss: 1.4549 - val_accuracy: 0.4398 - val_loss: 1.4259 - learning_rate: 0.0010
# Epoch 8/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4546 - loss: 1.4125
# Epoch 8: val_accuracy improved from 0.43982 to 0.50279, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.4546 - loss: 1.4125 - val_accuracy: 0.5028 - val_loss: 1.3062 - learning_rate: 0.0010
# Epoch 9/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4820 - loss: 1.3554
# Epoch 9: val_accuracy did not improve from 0.50279
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.4820 - loss: 1.3554 - val_accuracy: 0.4521 - val_loss: 1.3936 - learning_rate: 0.0010
# Epoch 10/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4971 - loss: 1.3234
# Epoch 10: val_accuracy improved from 0.50279 to 0.51579, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.4971 - loss: 1.3233 - val_accuracy: 0.5158 - val_loss: 1.2646 - learning_rate: 0.0010
# Epoch 11/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5143 - loss: 1.2909
# Epoch 11: val_accuracy improved from 0.51579 to 0.53975, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.5143 - loss: 1.2909 - val_accuracy: 0.5397 - val_loss: 1.2246 - learning_rate: 0.0010
# Epoch 12/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5220 - loss: 1.2681
# Epoch 12: val_accuracy improved from 0.53975 to 0.54885, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.5220 - loss: 1.2680 - val_accuracy: 0.5488 - val_loss: 1.1961 - learning_rate: 0.0010
# Epoch 13/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5389 - loss: 1.2512
# Epoch 13: val_accuracy did not improve from 0.54885
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.5389 - loss: 1.2512 - val_accuracy: 0.5347 - val_loss: 1.2066 - learning_rate: 0.0010
# Epoch 14/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5541 - loss: 1.2072
# Epoch 14: val_accuracy did not improve from 0.54885
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.5541 - loss: 1.2072 - val_accuracy: 0.5254 - val_loss: 1.2344 - learning_rate: 0.0010
# Epoch 15/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5715 - loss: 1.1763
# Epoch 15: val_accuracy improved from 0.54885 to 0.55182, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.5715 - loss: 1.1763 - val_accuracy: 0.5518 - val_loss: 1.1831 - learning_rate: 0.0010
# Epoch 16/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5706 - loss: 1.1654
# Epoch 16: val_accuracy improved from 0.55182 to 0.58284, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.5706 - loss: 1.1654 - val_accuracy: 0.5828 - val_loss: 1.1255 - learning_rate: 0.0010
# Epoch 17/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5843 - loss: 1.1437
# Epoch 17: val_accuracy did not improve from 0.58284
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.5843 - loss: 1.1437 - val_accuracy: 0.5602 - val_loss: 1.1632 - learning_rate: 0.0010
# Epoch 18/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5909 - loss: 1.1226
# Epoch 18: val_accuracy did not improve from 0.58284
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.5910 - loss: 1.1226 - val_accuracy: 0.5736 - val_loss: 1.1680 - learning_rate: 0.0010
# Epoch 19/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6011 - loss: 1.1009
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 19: val_accuracy improved from 0.58284 to 0.59287, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6011 - loss: 1.1009 - val_accuracy: 0.5929 - val_loss: 1.1272 - learning_rate: 0.0010
# Epoch 20/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6133 - loss: 1.0706
# Epoch 20: val_accuracy improved from 0.59287 to 0.60531, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6133 - loss: 1.0706 - val_accuracy: 0.6053 - val_loss: 1.0677 - learning_rate: 8.0000e-04
# Epoch 21/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6300 - loss: 1.0176
# Epoch 21: val_accuracy improved from 0.60531 to 0.60736, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6300 - loss: 1.0176 - val_accuracy: 0.6074 - val_loss: 1.0665 - learning_rate: 8.0000e-04
# Epoch 22/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6405 - loss: 1.0035
# Epoch 22: val_accuracy did not improve from 0.60736
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6405 - loss: 1.0035 - val_accuracy: 0.5994 - val_loss: 1.0930 - learning_rate: 8.0000e-04
# Epoch 23/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6387 - loss: 0.9896
# Epoch 23: val_accuracy improved from 0.60736 to 0.61014, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6387 - loss: 0.9896 - val_accuracy: 0.6101 - val_loss: 1.0589 - learning_rate: 8.0000e-04
# Epoch 24/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6535 - loss: 0.9620
# Epoch 24: val_accuracy did not improve from 0.61014
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6535 - loss: 0.9620 - val_accuracy: 0.5762 - val_loss: 1.1339 - learning_rate: 8.0000e-04
# Epoch 25/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6566 - loss: 0.9437
# Epoch 25: val_accuracy did not improve from 0.61014
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6566 - loss: 0.9437 - val_accuracy: 0.6038 - val_loss: 1.0894 - learning_rate: 8.0000e-04
# Epoch 26/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6695 - loss: 0.9175
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 26: val_accuracy did not improve from 0.61014
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6694 - loss: 0.9176 - val_accuracy: 0.6066 - val_loss: 1.0789 - learning_rate: 8.0000e-04
# Epoch 27/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6774 - loss: 0.8949
# Epoch 27: val_accuracy improved from 0.61014 to 0.63299, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6774 - loss: 0.8949 - val_accuracy: 0.6330 - val_loss: 1.0262 - learning_rate: 6.4000e-04
# Epoch 28/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6885 - loss: 0.8559
# Epoch 28: val_accuracy did not improve from 0.63299
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6884 - loss: 0.8559 - val_accuracy: 0.6270 - val_loss: 1.0424 - learning_rate: 6.4000e-04
# Epoch 29/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6931 - loss: 0.8342
# Epoch 29: val_accuracy did not improve from 0.63299
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6931 - loss: 0.8343 - val_accuracy: 0.6311 - val_loss: 1.0655 - learning_rate: 6.4000e-04
# Epoch 30/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6998 - loss: 0.8231
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 30: val_accuracy did not improve from 0.63299
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.6998 - loss: 0.8231 - val_accuracy: 0.6114 - val_loss: 1.1213 - learning_rate: 6.4000e-04
# Epoch 31/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7146 - loss: 0.7919
# Epoch 31: val_accuracy did not improve from 0.63299
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7146 - loss: 0.7919 - val_accuracy: 0.6226 - val_loss: 1.0760 - learning_rate: 5.1200e-04
# Epoch 32/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7239 - loss: 0.7703
# Epoch 32: val_accuracy did not improve from 0.63299
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7239 - loss: 0.7703 - val_accuracy: 0.6326 - val_loss: 1.0752 - learning_rate: 5.1200e-04
# Epoch 33/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7271 - loss: 0.7580
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 33: val_accuracy improved from 0.63299 to 0.63484, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7271 - loss: 0.7579 - val_accuracy: 0.6348 - val_loss: 1.0856 - learning_rate: 5.1200e-04
# Epoch 34/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7411 - loss: 0.7328
# Epoch 34: val_accuracy improved from 0.63484 to 0.64729, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7411 - loss: 0.7328 - val_accuracy: 0.6473 - val_loss: 1.0565 - learning_rate: 4.0960e-04
# Epoch 35/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7487 - loss: 0.7001
# Epoch 35: val_accuracy did not improve from 0.64729
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7487 - loss: 0.7002 - val_accuracy: 0.6367 - val_loss: 1.1205 - learning_rate: 4.0960e-04
# Epoch 36/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7472 - loss: 0.6910
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 36: val_accuracy did not improve from 0.64729
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7472 - loss: 0.6910 - val_accuracy: 0.6410 - val_loss: 1.0729 - learning_rate: 4.0960e-04
# Epoch 37/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7580 - loss: 0.6762
# Epoch 37: val_accuracy did not improve from 0.64729
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7581 - loss: 0.6761 - val_accuracy: 0.6454 - val_loss: 1.0965 - learning_rate: 3.2768e-04
# Epoch 38/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7649 - loss: 0.6565
# Epoch 38: val_accuracy did not improve from 0.64729
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7649 - loss: 0.6565 - val_accuracy: 0.6399 - val_loss: 1.1038 - learning_rate: 3.2768e-04
# Epoch 39/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7718 - loss: 0.6370
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 39: val_accuracy did not improve from 0.64729
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7718 - loss: 0.6370 - val_accuracy: 0.6421 - val_loss: 1.1163 - learning_rate: 3.2768e-04
# Epoch 40/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7746 - loss: 0.6244
# Epoch 40: val_accuracy did not improve from 0.64729
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7746 - loss: 0.6244 - val_accuracy: 0.6469 - val_loss: 1.0884 - learning_rate: 2.6214e-04
# Epoch 41/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7817 - loss: 0.5973
# Epoch 41: val_accuracy did not improve from 0.64729
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7817 - loss: 0.5973 - val_accuracy: 0.6449 - val_loss: 1.1257 - learning_rate: 2.6214e-04
# Epoch 42/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7886 - loss: 0.5863
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 42: val_accuracy improved from 0.64729 to 0.64933, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.7886 - loss: 0.5864 - val_accuracy: 0.6493 - val_loss: 1.1221 - learning_rate: 2.6214e-04
# Epoch 43/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7953 - loss: 0.5795
# Epoch 43: val_accuracy improved from 0.64933 to 0.65286, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7953 - loss: 0.5795 - val_accuracy: 0.6529 - val_loss: 1.1149 - learning_rate: 2.0972e-04
# Epoch 44/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7981 - loss: 0.5572
# Epoch 44: val_accuracy did not improve from 0.65286
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7981 - loss: 0.5572 - val_accuracy: 0.6478 - val_loss: 1.1247 - learning_rate: 2.0972e-04
# Epoch 45/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8024 - loss: 0.5472
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 45: val_accuracy did not improve from 0.65286
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8024 - loss: 0.5473 - val_accuracy: 0.6525 - val_loss: 1.1062 - learning_rate: 2.0972e-04
# Epoch 46/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8073 - loss: 0.5479
# Epoch 46: val_accuracy improved from 0.65286 to 0.65527, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.8073 - loss: 0.5479 - val_accuracy: 0.6553 - val_loss: 1.1380 - learning_rate: 1.6777e-04
# Epoch 47/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8104 - loss: 0.5302
# Epoch 47: val_accuracy improved from 0.65527 to 0.65936, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8104 - loss: 0.5301 - val_accuracy: 0.6594 - val_loss: 1.1288 - learning_rate: 1.6777e-04
# Epoch 48/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8117 - loss: 0.5220
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 48: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8117 - loss: 0.5220 - val_accuracy: 0.6536 - val_loss: 1.1498 - learning_rate: 1.6777e-04
# Epoch 49/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8194 - loss: 0.5111
# Epoch 49: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8194 - loss: 0.5111 - val_accuracy: 0.6573 - val_loss: 1.1484 - learning_rate: 1.3422e-04
# Epoch 50/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8258 - loss: 0.5028
# Epoch 50: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8258 - loss: 0.5028 - val_accuracy: 0.6536 - val_loss: 1.1475 - learning_rate: 1.3422e-04
# Epoch 51/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8248 - loss: 0.5001
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 51: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8247 - loss: 0.5001 - val_accuracy: 0.6579 - val_loss: 1.1637 - learning_rate: 1.3422e-04
# Epoch 52/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8266 - loss: 0.4881
# Epoch 52: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8266 - loss: 0.4881 - val_accuracy: 0.6571 - val_loss: 1.1811 - learning_rate: 1.0737e-04
# Epoch 53/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8242 - loss: 0.4957
# Epoch 53: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.8242 - loss: 0.4957 - val_accuracy: 0.6568 - val_loss: 1.1843 - learning_rate: 1.0737e-04
# Epoch 54/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8311 - loss: 0.4774
# Epoch 54: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 54: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8311 - loss: 0.4774 - val_accuracy: 0.6549 - val_loss: 1.2173 - learning_rate: 1.0737e-04
# Epoch 55/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8327 - loss: 0.4690
# Epoch 55: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8327 - loss: 0.4690 - val_accuracy: 0.6564 - val_loss: 1.2001 - learning_rate: 8.5899e-05
# Epoch 56/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8342 - loss: 0.4697
# Epoch 56: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8342 - loss: 0.4697 - val_accuracy: 0.6575 - val_loss: 1.1916 - learning_rate: 8.5899e-05
# Epoch 57/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8332 - loss: 0.4667
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 57: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8332 - loss: 0.4667 - val_accuracy: 0.6555 - val_loss: 1.1891 - learning_rate: 8.5899e-05
# Epoch 58/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8387 - loss: 0.4570
# Epoch 58: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.8387 - loss: 0.4570 - val_accuracy: 0.6588 - val_loss: 1.2006 - learning_rate: 6.8719e-05
# Epoch 59/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8405 - loss: 0.4549
# Epoch 59: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.8405 - loss: 0.4549 - val_accuracy: 0.6540 - val_loss: 1.2199 - learning_rate: 6.8719e-05
# Epoch 60/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8426 - loss: 0.4479
# Epoch 60: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 60: val_accuracy did not improve from 0.65936
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.8426 - loss: 0.4479 - val_accuracy: 0.6534 - val_loss: 1.2107 - learning_rate: 6.8719e-05
# Epoch 61/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8398 - loss: 0.4409
# Epoch 61: val_accuracy improved from 0.65936 to 0.65955, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8398 - loss: 0.4409 - val_accuracy: 0.6595 - val_loss: 1.2291 - learning_rate: 5.4976e-05
# Epoch 62/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8504 - loss: 0.4312
# Epoch 62: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8504 - loss: 0.4312 - val_accuracy: 0.6566 - val_loss: 1.2186 - learning_rate: 5.4976e-05
# Epoch 63/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8447 - loss: 0.4441
# Epoch 63: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 63: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8447 - loss: 0.4441 - val_accuracy: 0.6547 - val_loss: 1.2103 - learning_rate: 5.4976e-05
# Epoch 64/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8431 - loss: 0.4417
# Epoch 64: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8431 - loss: 0.4417 - val_accuracy: 0.6575 - val_loss: 1.2287 - learning_rate: 4.3980e-05
# Epoch 65/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8465 - loss: 0.4309
# Epoch 65: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8465 - loss: 0.4309 - val_accuracy: 0.6581 - val_loss: 1.2440 - learning_rate: 4.3980e-05
# Epoch 66/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8446 - loss: 0.4351
# Epoch 66: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
#
# Epoch 66: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8446 - loss: 0.4351 - val_accuracy: 0.6551 - val_loss: 1.2337 - learning_rate: 4.3980e-05
# Epoch 67/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8535 - loss: 0.4188
# Epoch 67: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8535 - loss: 0.4188 - val_accuracy: 0.6568 - val_loss: 1.2370 - learning_rate: 3.5184e-05
# Epoch 68/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8489 - loss: 0.4287
# Epoch 68: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8489 - loss: 0.4287 - val_accuracy: 0.6568 - val_loss: 1.2338 - learning_rate: 3.5184e-05
# Epoch 69/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8492 - loss: 0.4280
# Epoch 69: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
#
# Epoch 69: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8492 - loss: 0.4280 - val_accuracy: 0.6581 - val_loss: 1.2403 - learning_rate: 3.5184e-05
# Epoch 70/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8503 - loss: 0.4237
# Epoch 70: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8503 - loss: 0.4237 - val_accuracy: 0.6575 - val_loss: 1.2372 - learning_rate: 2.8147e-05
# Epoch 71/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8563 - loss: 0.4094
# Epoch 71: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8563 - loss: 0.4095 - val_accuracy: 0.6556 - val_loss: 1.2433 - learning_rate: 2.8147e-05
# Epoch 72/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8541 - loss: 0.4202
# Epoch 72: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
#
# Epoch 72: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8541 - loss: 0.4202 - val_accuracy: 0.6568 - val_loss: 1.2472 - learning_rate: 2.8147e-05
# Epoch 73/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8571 - loss: 0.4126
# Epoch 73: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8571 - loss: 0.4126 - val_accuracy: 0.6568 - val_loss: 1.2461 - learning_rate: 2.2518e-05
# Epoch 74/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8527 - loss: 0.4149
# Epoch 74: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.8527 - loss: 0.4149 - val_accuracy: 0.6594 - val_loss: 1.2520 - learning_rate: 2.2518e-05
# Epoch 75/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8549 - loss: 0.4134
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
#
# Epoch 75: val_accuracy did not improve from 0.65955
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8549 - loss: 0.4134 - val_accuracy: 0.6575 - val_loss: 1.2508 - learning_rate: 2.2518e-05
# Epoch 76/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8518 - loss: 0.4135
# Epoch 76: val_accuracy improved from 0.65955 to 0.65973, saving model to modelo_01_expressoes.keras
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.8518 - loss: 0.4135 - val_accuracy: 0.6597 - val_loss: 1.2579 - learning_rate: 1.8014e-05
# Epoch 77/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8575 - loss: 0.4066
# Epoch 77: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8575 - loss: 0.4066 - val_accuracy: 0.6588 - val_loss: 1.2529 - learning_rate: 1.8014e-05
# Epoch 78/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8560 - loss: 0.4065
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
#
# Epoch 78: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8560 - loss: 0.4065 - val_accuracy: 0.6566 - val_loss: 1.2519 - learning_rate: 1.8014e-05
# Epoch 79/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8561 - loss: 0.4036
# Epoch 79: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8561 - loss: 0.4036 - val_accuracy: 0.6558 - val_loss: 1.2546 - learning_rate: 1.4412e-05
# Epoch 80/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8538 - loss: 0.4101
# Epoch 80: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8538 - loss: 0.4101 - val_accuracy: 0.6564 - val_loss: 1.2542 - learning_rate: 1.4412e-05
# Epoch 81/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8546 - loss: 0.4132
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
#
# Epoch 81: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8547 - loss: 0.4132 - val_accuracy: 0.6564 - val_loss: 1.2527 - learning_rate: 1.4412e-05
# Epoch 82/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8553 - loss: 0.4109
# Epoch 82: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8553 - loss: 0.4109 - val_accuracy: 0.6577 - val_loss: 1.2539 - learning_rate: 1.1529e-05
# Epoch 83/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8550 - loss: 0.4136
# Epoch 83: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8550 - loss: 0.4136 - val_accuracy: 0.6562 - val_loss: 1.2574 - learning_rate: 1.1529e-05
# Epoch 84/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8635 - loss: 0.4000
# Epoch 84: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
#
# Epoch 84: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8635 - loss: 0.4000 - val_accuracy: 0.6568 - val_loss: 1.2535 - learning_rate: 1.1529e-05
# Epoch 85/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8563 - loss: 0.4072
# Epoch 85: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8563 - loss: 0.4072 - val_accuracy: 0.6558 - val_loss: 1.2611 - learning_rate: 9.2234e-06
# Epoch 86/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8546 - loss: 0.4064
# Epoch 86: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8546 - loss: 0.4064 - val_accuracy: 0.6575 - val_loss: 1.2638 - learning_rate: 9.2234e-06
# Epoch 87/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8580 - loss: 0.3949
# Epoch 87: ReduceLROnPlateau reducing learning rate to 7.378698501270265e-06.
#
# Epoch 87: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8580 - loss: 0.3949 - val_accuracy: 0.6547 - val_loss: 1.2665 - learning_rate: 9.2234e-06
# Epoch 88/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8580 - loss: 0.4028
# Epoch 88: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.8580 - loss: 0.4029 - val_accuracy: 0.6566 - val_loss: 1.2615 - learning_rate: 7.3787e-06
# Epoch 89/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8604 - loss: 0.3953
# Epoch 89: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.8604 - loss: 0.3953 - val_accuracy: 0.6566 - val_loss: 1.2590 - learning_rate: 7.3787e-06
# Epoch 90/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8585 - loss: 0.4029
# Epoch 90: ReduceLROnPlateau reducing learning rate to 5.902958946535364e-06.
#
# Epoch 90: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8585 - loss: 0.4029 - val_accuracy: 0.6562 - val_loss: 1.2664 - learning_rate: 7.3787e-06
# Epoch 91/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8613 - loss: 0.3990
# Epoch 91: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8613 - loss: 0.3990 - val_accuracy: 0.6560 - val_loss: 1.2615 - learning_rate: 5.9030e-06
# Epoch 92/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8594 - loss: 0.3972
# Epoch 92: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8594 - loss: 0.3972 - val_accuracy: 0.6568 - val_loss: 1.2602 - learning_rate: 5.9030e-06
# Epoch 93/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8560 - loss: 0.4138
# Epoch 93: ReduceLROnPlateau reducing learning rate to 4.7223671572282915e-06.
#
# Epoch 93: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8560 - loss: 0.4138 - val_accuracy: 0.6566 - val_loss: 1.2614 - learning_rate: 5.9030e-06
# Epoch 94/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8568 - loss: 0.4011
# Epoch 94: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8568 - loss: 0.4011 - val_accuracy: 0.6575 - val_loss: 1.2599 - learning_rate: 4.7224e-06
# Epoch 95/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8584 - loss: 0.4033
# Epoch 95: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.8584 - loss: 0.4033 - val_accuracy: 0.6560 - val_loss: 1.2602 - learning_rate: 4.7224e-06
# Epoch 96/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8598 - loss: 0.3959
# Epoch 96: ReduceLROnPlateau reducing learning rate to 3.7778936530230567e-06.
#
# Epoch 96: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.8598 - loss: 0.3959 - val_accuracy: 0.6581 - val_loss: 1.2621 - learning_rate: 4.7224e-06
# Epoch 97/100
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8546 - loss: 0.4086
# Epoch 97: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.8546 - loss: 0.4086 - val_accuracy: 0.6562 - val_loss: 1.2591 - learning_rate: 3.7779e-06
# Epoch 98/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8593 - loss: 0.3973
# Epoch 98: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.8593 - loss: 0.3973 - val_accuracy: 0.6568 - val_loss: 1.2594 - learning_rate: 3.7779e-06
# Epoch 99/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8567 - loss: 0.3991
# Epoch 99: ReduceLROnPlateau reducing learning rate to 3.0223149224184457e-06.
#
# Epoch 99: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.8567 - loss: 0.3991 - val_accuracy: 0.6568 - val_loss: 1.2606 - learning_rate: 3.7779e-06
# Epoch 100/100
# 476/477 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8556 - loss: 0.4001
# Epoch 100: val_accuracy did not improve from 0.65973
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.8556 - loss: 0.4001 - val_accuracy: 0.6566 - val_loss: 1.2613 - learning_rate: 3.0223e-06

# %%
history

# %%
loaded_model = tensorflow.keras.models.load_model('modelo_01_expressoes.keras')

# %%
Y_predicted = loaded_model.predict(X_val)
# Out:
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step

# %%
yp = Y_predicted.tolist()
yt = y_val.tolist()
y_pred = []
y_true = []

# %%
len(yp)
# Out:
# 5384

# %%
len(yt)
# Out:
# 5384

# %%
for i in range(len(yt)):
    y_pred.append(np.argmax(yp[i]))
    y_true.append(np.argmax(yt[i]))

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
print(cm)
# Out:
# [[ 425   12   64   42   94    6  112]
#  [  22   46    5    2    4    1    1]
#  [  86    6  356   43  165   56   89]
#  [  33    0   15 1136   31   22   70]
#  [  96    0   65   45  501    2  191]
#  [  12    1   71   44   10  447   16]
#  [  57    1   34   75  123    8  641]]

# %%
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(len(emotions))
plt.xticks(tick_marks, emotions, rotation = 45)
plt.yticks(tick_marks, emotions, rotation = 0)
# Out:
# ([<matplotlib.axis.YTick at 0x7f3c35732c90>,
#   <matplotlib.axis.YTick at 0x7f3c357910a0>,
#   <matplotlib.axis.YTick at 0x7f3c3610d940>,
#   <matplotlib.axis.YTick at 0x7f3c3418aba0>,
#   <matplotlib.axis.YTick at 0x7f3c34189be0>,
#   <matplotlib.axis.YTick at 0x7f3c3418b470>,
#   <matplotlib.axis.YTick at 0x7f3c3418be60>],
#  [Text(0, 0, 'Angry'),
#   Text(0, 1, 'Disgusted'),
#   Text(0, 2, 'Afraid'),
#   Text(0, 3, 'Happy'),
#   Text(0, 4, 'Neutral'),
#   Text(0, 5, 'Sad'),
#   Text(0, 6, 'Surprised')])

# %% [markdown]
# ## Testando o modelo

# %%
img_path = './Material/testes/teste02.jpg'
image = cv2.imread(img_path)

# %%
original = image.copy()
grayscale = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
plt.imshow(grayscale)

# %%
face_detector = cv2.CascadeClassifier('./Material/haarcascade_frontalface_default.xml')
faces = face_detector.detectMultiScale(grayscale, 1.1, 3)

# %%
for (x, y, w, h) in faces:
    original = cv2.rectangle(original, (x, y), (x + w, y + h), (255, 0, 0), 1)
    roi_gray = grayscale[y:y+h, x:x + w]
    roi_gray = normalize(roi_gray)
    roi_gray = cv2.resize(roi_gray, (image_size, image_size))
    dimensioned = np.expand_dims(roi_gray, -1)
    dimensioned = np.expand_dims(dimensioned, 0)
    prediction = loaded_model.predict(dimensioned)[0]
    label = emotions[int(np.argmax(prediction))]
    cv2.putText(original, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,0,0), 2, cv2.LINE_AA)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
plt.imshow(cv2.cvtColor(original, cv2.COLOR_BGR2RGB))
